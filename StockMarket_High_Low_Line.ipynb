# %% [markdown]
# <a href="https://colab.research.google.com/github/wellmej/Python-DataViz/blob/master/StockMarket_High_Low_Line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_stock_market = pd.read_csv('HistoricalQuotes2.csv')

# %%
df_stock_market
# Out:
#          Date  Close_Last   Volume        Open        High         Low
# 0   9/14/2020  $1,519.28   1696589  $1,539.01   $1,564.00   $1,515.74
# 1   9/11/2020  $1,520.72   1597087     $1,536   $1,575.20   $1,497.36
# 2   9/10/2020  $1,532.02   1618557  $1,560.64   $1,584.08   $1,525.81
# 3    9/9/2020  $1,556.96   1774704  $1,557.53      $1,569   $1,536.05
# 4    9/8/2020  $1,532.39   2610884  $1,533.51   $1,563.87   $1,528.01
# ..        ...         ...      ...         ...         ...         ...
# 89   5/7/2020  $1,372.56   1399759  $1,365.94   $1,377.60   $1,355.27
# 90   5/6/2020  $1,347.30   1215423  $1,361.69   $1,371.12   $1,347.29
# 91   5/5/2020  $1,351.11   1651533  $1,337.92   $1,373.94   $1,337.46
# 92   5/4/2020  $1,326.80   1504017  $1,308.23   $1,327.66      $1,299
# 93   5/1/2020  $1,320.61   2072639  $1,328.50   $1,352.07      $1,311
#
# [94 rows x 6 columns]

# %%
#
# Convert date values to date-time format (yyyy-mm-dd)
#
df_stock_market["new_date"] = pd.to_datetime(df_stock_market["Date"])

# %%
df_stock_market["new_date"]
# Out:
# 0    2020-09-14
# 1    2020-09-11
# 2    2020-09-10
# 3    2020-09-09
# 4    2020-09-08
#         ...
# 89   2020-05-07
# 90   2020-05-06
# 91   2020-05-05
# 92   2020-05-04
# 93   2020-05-01
# Name: new_date, Length: 94, dtype: datetime64[ns]

# %%
df_stock_market[" High"]
# Out:
# 0     $1,564.00
# 1     $1,575.20
# 2     $1,584.08
# 3        $1,569
# 4     $1,563.87
#          ...
# 89    $1,377.60
# 90    $1,371.12
# 91    $1,373.94
# 92    $1,327.66
# 93    $1,352.07
# Name:  High, Length: 94, dtype: object

# %%
labels = ['High', 'Low']
plt.figure(figsize = (20, 8))
plt.plot(df_stock_market["new_date"], df_stock_market[' High'])
plt.plot(df_stock_market["new_date"], df_stock_market[' Low'])
plt.title('Historical Stock Market', fontsize = 14, fontweight = 'bold')
plt.ylabel("Market Value")
plt.legend(labels = labels, fontsize = 'large')
plt.show()

# %%
df_stock_market_subset = df_stock_market[(df_stock_market.new_date >= '2020-07-01') & (df_stock_market.new_date <= '2020-08-30') ]

# %%
df_stock_market_subset
# Out:
#          Date  Close_Last   Volume  ...        High         Low   new_date
# 10  8/28/2020  $1,644.41   1499782  ...  $1,647.17   $1,630.75  2020-08-28
# 11  8/27/2020  $1,634.33   1861602  ...     $1,655   $1,625.75  2020-08-27
# 12  8/26/2020  $1,652.38   3581072  ...  $1,659.22   $1,603.60  2020-08-26
# 13  8/25/2020  $1,608.22   2132084  ...  $1,611.62   $1,582.07  2020-08-25
# 14  8/24/2020  $1,588.20   1410229  ...  $1,614.17   $1,580.57  2020-08-24
# 15  8/21/2020  $1,580.42   1446453  ...  $1,597.72   $1,568.01  2020-08-21
# 16  8/20/2020  $1,581.75   1706877  ...  $1,585.87   $1,538.20  2020-08-20
# 17  8/19/2020  $1,547.53   1660611  ...  $1,573.68   $1,543.95  2020-08-19
# 18  8/18/2020  $1,558.60   2027086  ...  $1,562.47   $1,523.71  2020-08-18
# 19  8/17/2020  $1,517.98   1378600  ...  $1,525.61   $1,507.97  2020-08-17
# 20  8/14/2020  $1,507.73   1355200  ...  $1,521.90   $1,502.88  2020-08-14
# ...

# %%
labels = ['High', 'Low']

plt.figure(figsize = (20, 16))
plt.plot(df_stock_market_subset["new_date"], df_stock_market_subset[' High'], label = 'High', color = 'midnightblue')
plt.plot(df_stock_market_subset["new_date"], df_stock_market_subset[' Low'], label = 'Low', color='crimson')

plt.title('Historical Stock Market', fontsize = 14, fontweight = 'bold')
plt.ylabel("Market Value")
plt.xlabel('Date')
plt.legend(labels = labels, fontsize = 'large')
plt.show()

# %%
# line 1 points
x1 = [10,25,30]
y1 = [20,40,10]
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1")
# line 2 points
x2 = [10,20,35]
y2 = [40,10,30]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")
plt.xlabel('x - axis')
# Set the y axis label of the current axis.
plt.ylabel('y - axis')
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
labels = ['High', 'Low']
plt.figure(figsize = (20, 8))
plt.plot(df_stock_market["new_date"], df_stock_market[' High'])
plt.plot(df_stock_market["new_date"], df_stock_market[' Low'])
plt.title('Historical Stock Market', fontsize = 14, fontweight = 'bold')
plt.ylabel("Market Value")
plt.legend(labels = labels, fontsize = 'large')
plt.show()
