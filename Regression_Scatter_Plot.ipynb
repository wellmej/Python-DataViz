# %% [markdown]
# <a href="https://colab.research.google.com/github/wellmej/Python-DataViz/blob/master/Regression_Scatter_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_sales = pd.read_csv('scatter_plot_ii.csv')

# %%
df_sales
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
#plt.figure(figsize = (12,8))
#plt.scatter(df_real_estate['size'],
#            df_real_estate['price-k'])
#plt.show()

# %%
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_sales)
plt.show()

# %%
#
# Increase Plot Size
#
plt.figure(figsize = (12,8))
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_sales)
plt.show()

# %%
#
# Increase Plot Size using Seaborn
#
sns.set(rc = {'figure.figsize': (9,6)})
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_sales)
plt.show()

# %%
#
# Changing colors 
#  Black points
#  Red trend line
#
sns.set(rc = {'figure.figsize': (9,6)})
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_sales,
            scatter_kws = {'color': 'k'},
            line_kws = {'color': 'red'})
plt.show()

# %%
#
# Add title and labels
#
sns.set(rc = {'figure.figsize': (10,8)})
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_sales,
            scatter_kws = {'color': 'k'},
            line_kws = {'color': 'red'})
plt.xlabel('AD Expenditure in $1,000s')
plt.ylabel('Sales on Units in 1,000s')
plt.title('Effect of AD Expenditure on Sales', fontsize = 14, weight = 'bold')
plt.show()

# %%
#
# Use lmplot (google the difference between regplot and lmplot)
#
sns.lmplot(x = 'Budget',
           y = 'Sales',
           data = df_sales,
           scatter_kws = {'color': 'k'},
            line_kws = {'color': 'red'},
           height = 10)  # Height sets both Height and Width attributes
plt.xlabel('AD Expenditure in $1,000s')
plt.ylabel('Sales on Units in 1,000s')
plt.title('Effect of AD Expenditure on Sales', fontsize = 14, weight = 'bold')
plt.show()
